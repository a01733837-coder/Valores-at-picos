# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('pais_filtrado_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26164 entries, 0 to 26163
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   instant_bookable             26164 non-null  object
#  1   property_type                26164 non-null  object
#  2   room_type                    26164 non-null  object
#  3   amenities                    26164 non-null  object
#  4   bathrooms_text               26164 non-null  object
#  5   host_name                    26164 non-null  object
#  6   host_location                26164 non-null  object
#  7   host_response_time           26164 non-null  object
#  8   host_is_superhost            26164 non-null  object
#  9   host_has_profile_pic         26164 non-null  object
#  10  host_identity_verified       26164 non-null  object
#  11  bedrooms                     26164 non-null  int64
#  12  beds                         26164 non-null  int64
#  13  accommodates                 26164 non-null  int64
#  14  host_since                   26164 non-null  object
#  15  host_response_rate           26164 non-null  object
#  16  host_acceptance_rate         26164 non-null  object
#  17  host_listings_count          26164 non-null  int64
#  18  host_total_listings_count    26164 non-null  int64
#  19  bathrooms                    26164 non-null  float64
#  20  has_availability             26164 non-null  object
#  21  price                        26164 non-null  object
#  22  minimum_nights               26164 non-null  int64
#  23  maximum_nights               26164 non-null  int64
#  24  minimum_minimum_nights       26164 non-null  int64
#  25  maximum_minimum_nights       26164 non-null  int64
#  26  minimum_maximum_nights       26164 non-null  int64
#  27  maximum_maximum_nights       26164 non-null  int64
#  28  availability_30              26164 non-null  int64
#  29  availability_60              26164 non-null  int64
#  30  availability_90              26164 non-null  int64
#  31  availability_365             26164 non-null  int64
#  32  number_of_reviews            26164 non-null  int64
#  33  number_of_reviews_ltm        26164 non-null  int64
#  34  number_of_reviews_l30d       26164 non-null  int64
#  35  number_of_reviews_ly         26164 non-null  int64
#  36  review_scores_rating         26164 non-null  float64
#  37  review_scores_accuracy       26164 non-null  float64
#  38  review_scores_cleanliness    26164 non-null  float64
#  39  review_scores_checkin        26164 non-null  float64
#  40  review_scores_communication  26164 non-null  float64
#  41  review_scores_location       26164 non-null  float64
#  42  review_scores_value          26164 non-null  float64
#  43  reviews_per_month            26164 non-null  float64
#  44  estimated_occupancy_l365d    26164 non-null  int64
#  45  estimated_revenue_l365d      26164 non-null  int64
#  46  latitude                     26164 non-null  float64
#  47  longitude                    26164 non-null  float64
# dtypes: float64(11), int64(21), object(16)
# memory usage: 9.6+ MB

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# instant_bookable               0
# property_type                  0
# room_type                      0
# amenities                      0
# bathrooms_text                 0
# host_name                      0
# host_location                  0
# host_response_time             0
# host_is_superhost              0
# host_has_profile_pic           0
# host_identity_verified         0
# bedrooms                       0
# beds                           0
# accommodates                   0
# host_since                     0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# bathrooms                      0
# has_availability               0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# minimum_minimum_nights         0
# maximum_minimum_nights         0
# minimum_maximum_nights         0
# maximum_maximum_nights         0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# number_of_reviews_ly           0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# estimated_occupancy_l365d      0
# estimated_revenue_l365d        0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_28072\419970050.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 =data.fillna(method="bfill")
#       instant_bookable                      property_type        room_type  \
# 0                    t                 Entire rental unit  Entire home/apt
# 1                    t  Private room in bed and breakfast     Private room
# 2                    f                 Entire rental unit  Entire home/apt
# 3                    f                 Entire rental unit  Entire home/apt
# 4                    t                 Entire rental unit  Entire home/apt
# ...                ...                                ...              ...
# 26159                t                       Entire condo  Entire home/apt
# 26160                t                       Entire condo  Entire home/apt
# 26161                t                       Entire villa  Entire home/apt
# 26162                t                       Entire villa  Entire home/apt
# 26163                f                 Entire rental unit  Entire home/apt
#
#                                                amenities  bathrooms_text  \
# 0      ["Hot water", "Bed linens", "Dining table", "W...       1.5 baths
# 1      ["Hot water", "Shampoo", "TV", "Crib", "Exteri...  1 private bath
# 2      ["Hot water", "Exterior security cameras on pr...          1 bath
# 3      ["Kitchen", "Hot tub", "Free parking on premis...          1 bath
# 4      ["Clothing storage: wardrobe", "Garden view", ...          1 bath
# ...                                                  ...             ...
# 26159  ["Hot water", "Cleaning available during stay"...          1 bath
# 26160  ["Hot water", "Cleaning available during stay"...          1 bath
# 26161  ["Hot water", "Crib", "High chair", "Bed linen...         4 baths
# 26162  ["Hot water", "Mosquito net", "Bed linens", "D...         2 baths
# 26163      ["Wifi", "Air conditioning", "Kitchen", "TV"]          1 bath
#
#         host_name      host_location host_response_time host_is_superhost  \
# 0       Emmanouil  Heraklion, Greece     within an hour                 t
# 1        Dimitris     Matala, Greece     within an hour                 f
# 2      Chryssoula     Chania, Greece     within an hour                 f
# 3        Georgios             Greece     within an hour                 f
# 4          George   Iraklion, Greece     within an hour                 t
# ...           ...                ...                ...               ...
# 26159       Arben            Unknown     within an hour                 t
# 26160       Arben            Unknown     within an hour                 t
# 26161     Giorgos   Rethimno, Greece     within an hour                 t
# 26162       Notos             Greece     within an hour                 f
# 26163    Καλλιόπη            Unknown     within an hour                 f
#
#       host_has_profile_pic  ... review_scores_cleanliness  \
# 0                        t  ...                      4.91
# 1                        t  ...                      4.49
# 2                        t  ...                      4.67
# 3                        t  ...                      5.00
# 4                        t  ...                      4.80
# ...                    ...  ...                       ...
# 26159                    t  ...                      5.00
# 26160                    t  ...                      5.00
# 26161                    t  ...                      5.00
# 26162                    t  ...                      5.00
# 26163                    f  ...                      5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.96                         4.99
# 1                       4.33                         4.43
# 2                       4.87                         4.84
# 3                       5.00                         4.50
# 4                       4.92                         4.94
# ...                      ...                          ...
# 26159                   5.00                         5.00
# 26160                   5.00                         5.00
# 26161                   5.00                         5.00
# 26162                   5.00                         5.00
# 26163                   5.00                         5.00
#
#        review_scores_location review_scores_value reviews_per_month  \
# 0                        4.64                4.92              0.82
# 1                        4.50                4.18              0.26
# 2                        4.94                4.66              2.12
# 3                        4.00                4.50              0.01
# 4                        4.68                4.88              0.98
# ...                       ...                 ...               ...
# 26159                    4.80                4.90              0.30
# 26160                    4.80                4.90              0.30
# 26161                    4.80                4.90              0.30
# 26162                    4.80                4.90              0.30
# 26163                    4.80                4.90              0.30
#
#       estimated_occupancy_l365d  estimated_revenue_l365d   latitude  longitude
# 0                            48                     2352  35.330120  25.080120
# 1                             6                      432  34.995330  24.756540
# 2                           168                        0  35.514390  24.017930
# 3                             0                        0  35.496480  23.696480
# 4                           100                     7000  35.396160  25.025410
# ...                         ...                      ...        ...        ...
# 26159                         0                        0  35.512959  24.015141
# 26160                         0                        0  35.512959  24.015141
# 26161                         0                        0  35.343478  24.727593
# 26162                         0                        0  35.200249  24.417222
# 26163                         0                        0  35.211579  26.109334
#
# [26164 rows x 48 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# instant_bookable               0
# property_type                  0
# room_type                      0
# amenities                      0
# bathrooms_text                 0
# host_name                      0
# host_location                  0
# host_response_time             0
# host_is_superhost              0
# host_has_profile_pic           0
# host_identity_verified         0
# bedrooms                       0
# beds                           0
# accommodates                   0
# host_since                     0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# bathrooms                      0
# has_availability               0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# minimum_minimum_nights         0
# maximum_minimum_nights         0
# minimum_maximum_nights         0
# maximum_maximum_nights         0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# number_of_reviews_ly           0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# estimated_occupancy_l365d      0
# estimated_revenue_l365d        0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
#Creo 2 dataframe para poder procesar los outliers
cualitativas= data1.iloc[ : , 0:11 ]
cuantitativas= data1.iloc[ : , 11:48 ]

# %%
cuantitativas.columns
# Out:
# Index(['bedrooms', 'beds', 'accommodates', 'host_since', 'host_response_rate',
#        'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'bathrooms', 'has_availability', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'number_of_reviews_ly', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month',
#        'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
cualitativas.columns
# Out:
# Index(['instant_bookable', 'property_type', 'room_type', 'amenities',
#        'bathrooms_text', 'host_name', 'host_location', 'host_response_time',
#        'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified'],
#       dtype='object')

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
data1["indice_tiempo"] = pd.to_datetime(data1.get("indice_tiempo"), format="%d/%m/%Y", errors="ignore")
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_28072\946277982.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data1["indice_tiempo"] = pd.to_datetime(data1.get("indice_tiempo"), format="%d/%m/%Y", errors="ignore")

# %%
cuantitativas = data1.select_dtypes(include=[np.number])     # <- DataFrame numérico
y = cuantitativas.copy()

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido bedrooms                           6.291825
# beds                               9.712709
# accommodates                      13.027427
# host_listings_count              594.470607
# host_total_listings_count       1198.557956
# bathrooms                          5.206521
# minimum_nights                   125.365328
# maximum_nights                  1912.737685
# minimum_minimum_nights            43.075780
# maximum_minimum_nights           128.350676
# minimum_maximum_nights          2082.994642
# maximum_maximum_nights          2078.988343
# availability_30                   49.418497
# availability_60                   96.694026
# availability_90                  140.924902
# availability_365                 522.196296
# number_of_reviews                124.096311
# number_of_reviews_ltm             26.161030
# number_of_reviews_l30d             0.942459
# number_of_reviews_ly              26.158870
# review_scores_rating               5.682579
# review_scores_accuracy             5.741276
# review_scores_cleanliness          5.704419
# review_scores_checkin              5.690976
# review_scores_communication        5.695835
# review_scores_location             5.607864
# review_scores_value                5.735308
# reviews_per_month                  2.098639
# estimated_occupancy_l365d        170.010173
# estimated_revenue_l365d        49570.893905
# latitude                          35.809630
# longitude                         26.661814
# dtype: float64
# Limite inferior permitido bedrooms                          -2.340518
# beds                              -3.494700
# accommodates                      -3.443724
# host_listings_count             -483.087791
# host_total_listings_count      -1015.287738
# bathrooms                         -1.829996
# minimum_nights                  -114.917766
# maximum_nights                  -795.861978
# minimum_minimum_nights           -36.778578
# maximum_minimum_nights          -115.995608
# minimum_maximum_nights          -683.474003
# maximum_maximum_nights          -596.140995
# availability_30                  -21.352299
# availability_60                  -32.679120
# availability_90                  -42.090015
# availability_365                -127.009857
# number_of_reviews                -85.503664
# number_of_reviews_ltm            -17.209952
# number_of_reviews_l30d            -0.849354
# number_of_reviews_ly             -17.221628
# review_scores_rating               4.013538
# review_scores_accuracy             3.943114
# review_scores_cleanliness          4.054631
# review_scores_checkin              4.108843
# review_scores_communication        4.128276
# review_scores_location             3.937468
# review_scores_value                3.866180
# reviews_per_month                 -1.149402
# estimated_occupancy_l365d       -107.892607
# estimated_revenue_l365d       -41447.847276
# latitude                          34.888117
# longitude                         22.583307
# dtype: float64

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        bedrooms  beds  accommodates  host_listings_count  \
# 0           1.0   1.0           3.0                  3.0
# 1           1.0   2.0           4.0                  4.0
# 2           1.0   2.0           2.0                  4.0
# 3           1.0   2.0           6.0                  1.0
# 4           1.0   1.0           2.0                 15.0
# ...         ...   ...           ...                  ...
# 26159       1.0   1.0           2.0                 10.0
# 26160       1.0   1.0           2.0                 10.0
# 26161       4.0   6.0          10.0                 87.0
# 26162       3.0   4.0           6.0                 13.0
# 26163       1.0   2.0           4.0                  4.0
#
#        host_total_listings_count  bathrooms  minimum_nights  maximum_nights  \
# 0                            3.0        1.5             3.0            15.0
# 1                            4.0        1.0             1.0          1125.0
# 2                            4.0        1.7             4.0            30.0
# 3                            1.0        1.0             3.0           730.0
# 4                           15.0        1.0             5.0            28.0
# ...                          ...        ...             ...             ...
# 26159                       10.0        1.0             3.0           365.0
# 26160                       10.0        1.0             3.0           365.0
# 26161                       97.0        4.0             1.0          1125.0
# 26162                       25.0        2.0             6.0            45.0
# 26163                        4.0        1.0             1.0           365.0
#
#        minimum_minimum_nights  maximum_minimum_nights  ...  \
# 0                         3.0                     3.0  ...
# 1                         1.0                     1.0  ...
# 2                         4.0                     4.0  ...
# 3                         3.0                     3.0  ...
# 4                         5.0                     7.0  ...
# ...                       ...                     ...  ...
# 26159                     3.0                     3.0  ...
# 26160                     3.0                     3.0  ...
# 26161                     1.0                     7.0  ...
# 26162                     5.0                     7.0  ...
# 26163                     1.0                     1.0  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.91                   4.96
# 1                           4.49                   4.33
# 2                           4.67                   4.87
# 3                           5.00                   5.00
# 4                           4.80                   4.92
# ...                          ...                    ...
# 26159                       5.00                   5.00
# 26160                       5.00                   5.00
# 26161                       5.00                   5.00
# 26162                       5.00                   5.00
# 26163                       5.00                   5.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.99                    4.64
# 1                             4.43                    4.50
# 2                             4.84                    4.94
# 3                             4.50                    4.00
# 4                             4.94                    4.68
# ...                            ...                     ...
# 26159                         5.00                    4.80
# 26160                         5.00                    4.80
# 26161                         5.00                    4.80
# 26162                         5.00                    4.80
# 26163                         5.00                    4.80
#
#        review_scores_value  reviews_per_month  estimated_occupancy_l365d  \
# 0                     4.92               0.82                       48.0
# 1                     4.18               0.26                        6.0
# 2                     4.66                NaN                      168.0
# 3                     4.50               0.01                        0.0
# 4                     4.88               0.98                      100.0
# ...                    ...                ...                        ...
# 26159                 4.90               0.30                        0.0
# 26160                 4.90               0.30                        0.0
# 26161                 4.90               0.30                        0.0
# 26162                 4.90               0.30                        0.0
# 26163                 4.90               0.30                        0.0
#
#        estimated_revenue_l365d   latitude  longitude
# 0                       2352.0  35.330120  25.080120
# 1                        432.0  34.995330  24.756540
# 2                          0.0  35.514390  24.017930
# 3                          0.0  35.496480  23.696480
# 4                       7000.0  35.396160  25.025410
# ...                        ...        ...        ...
# 26159                      0.0  35.512959  24.015141
# 26160                      0.0  35.512959  24.015141
# 26161                      0.0  35.343478  24.727593
# 26162                      0.0  35.200249  24.417222
# 26163                      0.0  35.211579  26.109334
#
# [26164 rows x 32 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# bedrooms                       336
# beds                           423
# accommodates                   546
# host_listings_count            586
# host_total_listings_count      335
# bathrooms                      547
# minimum_nights                  91
# maximum_nights                   1
# minimum_minimum_nights          47
# maximum_minimum_nights         102
# minimum_maximum_nights           0
# maximum_maximum_nights           0
# availability_30                  0
# availability_60                  0
# availability_90                  0
# availability_365                 0
# number_of_reviews              503
# number_of_reviews_ltm          466
# number_of_reviews_l30d         886
# number_of_reviews_ly           476
# review_scores_rating           664
# review_scores_accuracy         335
# review_scores_cleanliness      650
# review_scores_checkin          562
# review_scores_communication    518
# review_scores_location         277
# review_scores_value            359
# reviews_per_month              502
# estimated_occupancy_l365d      609
# estimated_revenue_l365d        207
# latitude                        25
# longitude                        0
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#        bedrooms  beds  accommodates  host_listings_count  \
# 0           1.0   1.0           3.0                  3.0
# 1           1.0   2.0           4.0                  4.0
# 2           1.0   2.0           2.0                  4.0
# 3           1.0   2.0           6.0                  1.0
# 4           1.0   1.0           2.0                 15.0
# ...         ...   ...           ...                  ...
# 26159       1.0   1.0           2.0                 10.0
# 26160       1.0   1.0           2.0                 10.0
# 26161       4.0   6.0          10.0                 87.0
# 26162       3.0   4.0           6.0                 13.0
# 26163       1.0   2.0           4.0                  4.0
#
#        host_total_listings_count  bathrooms  minimum_nights  maximum_nights  \
# 0                            3.0        1.5             3.0            15.0
# 1                            4.0        1.0             1.0          1125.0
# 2                            4.0        1.7             4.0            30.0
# 3                            1.0        1.0             3.0           730.0
# 4                           15.0        1.0             5.0            28.0
# ...                          ...        ...             ...             ...
# 26159                       10.0        1.0             3.0           365.0
# 26160                       10.0        1.0             3.0           365.0
# 26161                       97.0        4.0             1.0          1125.0
# 26162                       25.0        2.0             6.0            45.0
# 26163                        4.0        1.0             1.0           365.0
#
#        minimum_minimum_nights  maximum_minimum_nights  ...  \
# 0                         3.0                     3.0  ...
# 1                         1.0                     1.0  ...
# 2                         4.0                     4.0  ...
# 3                         3.0                     3.0  ...
# 4                         5.0                     7.0  ...
# ...                       ...                     ...  ...
# 26159                     3.0                     3.0  ...
# 26160                     3.0                     3.0  ...
# 26161                     1.0                     7.0  ...
# 26162                     5.0                     7.0  ...
# 26163                     1.0                     1.0  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.91                   4.96
# 1                           4.49                   4.33
# 2                           4.67                   4.87
# 3                           5.00                   5.00
# 4                           4.80                   4.92
# ...                          ...                    ...
# 26159                       5.00                   5.00
# 26160                       5.00                   5.00
# 26161                       5.00                   5.00
# 26162                       5.00                   5.00
# 26163                       5.00                   5.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.99                    4.64
# 1                             4.43                    4.50
# 2                             4.84                    4.94
# 3                             4.50                    4.00
# 4                             4.94                    4.68
# ...                            ...                     ...
# 26159                         5.00                    4.80
# 26160                         5.00                    4.80
# 26161                         5.00                    4.80
# 26162                         5.00                    4.80
# 26163                         5.00                    4.80
#
#        review_scores_value  reviews_per_month  estimated_occupancy_l365d  \
# 0                     4.92               0.82                       48.0
# 1                     4.18               0.26                        6.0
# 2                     4.66               0.40                      168.0
# 3                     4.50               0.01                        0.0
# 4                     4.88               0.98                      100.0
# ...                    ...                ...                        ...
# 26159                 4.90               0.30                        0.0
# 26160                 4.90               0.30                        0.0
# 26161                 4.90               0.30                        0.0
# 26162                 4.90               0.30                        0.0
# 26163                 4.90               0.30                        0.0
#
#        estimated_revenue_l365d   latitude  longitude
# 0                       2352.0  35.330120  25.080120
# 1                        432.0  34.995330  24.756540
# 2                          0.0  35.514390  24.017930
# 3                          0.0  35.496480  23.696480
# 4                       7000.0  35.396160  25.025410
# ...                        ...        ...        ...
# 26159                      0.0  35.512959  24.015141
# 26160                      0.0  35.512959  24.015141
# 26161                      0.0  35.343478  24.727593
# 26162                      0.0  35.200249  24.417222
# 26163                      0.0  35.211579  26.109334
#
# [26164 rows x 32 columns]

# %%
#Convertir DataFrame a CSV
data_clean.to_csv("pais_desviación.csv")

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# bedrooms                       0
# beds                           0
# accommodates                   0
# host_listings_count            0
# host_total_listings_count      0
# bathrooms                      0
# minimum_nights                 0
# maximum_nights                 0
# minimum_minimum_nights         0
# maximum_minimum_nights         0
# minimum_maximum_nights         0
# maximum_maximum_nights         0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# number_of_reviews_ly           0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# estimated_occupancy_l365d      0
# estimated_revenue_l365d        0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios_desviación = pd.concat([cualitativas, data_clean], axis=1)
Datos_limpios_desviación
# Out:
#       instant_bookable                      property_type        room_type  \
# 0                    t                 Entire rental unit  Entire home/apt
# 1                    t  Private room in bed and breakfast     Private room
# 2                    f                 Entire rental unit  Entire home/apt
# 3                    f                 Entire rental unit  Entire home/apt
# 4                    t                 Entire rental unit  Entire home/apt
# ...                ...                                ...              ...
# 26159                t                       Entire condo  Entire home/apt
# 26160                t                       Entire condo  Entire home/apt
# 26161                t                       Entire villa  Entire home/apt
# 26162                t                       Entire villa  Entire home/apt
# 26163                f                 Entire rental unit  Entire home/apt
#
#                                                amenities  bathrooms_text  \
# 0      ["Hot water", "Bed linens", "Dining table", "W...       1.5 baths
# 1      ["Hot water", "Shampoo", "TV", "Crib", "Exteri...  1 private bath
# 2      ["Hot water", "Exterior security cameras on pr...          1 bath
# 3      ["Kitchen", "Hot tub", "Free parking on premis...          1 bath
# 4      ["Clothing storage: wardrobe", "Garden view", ...          1 bath
# ...                                                  ...             ...
# 26159  ["Hot water", "Cleaning available during stay"...          1 bath
# 26160  ["Hot water", "Cleaning available during stay"...          1 bath
# 26161  ["Hot water", "Crib", "High chair", "Bed linen...         4 baths
# 26162  ["Hot water", "Mosquito net", "Bed linens", "D...         2 baths
# 26163      ["Wifi", "Air conditioning", "Kitchen", "TV"]          1 bath
#
#         host_name      host_location host_response_time host_is_superhost  \
# 0       Emmanouil  Heraklion, Greece     within an hour                 t
# 1        Dimitris     Matala, Greece     within an hour                 f
# 2      Chryssoula     Chania, Greece     within an hour                 f
# 3        Georgios             Greece     within an hour                 f
# 4          George   Iraklion, Greece     within an hour                 t
# ...           ...                ...                ...               ...
# 26159       Arben            Unknown     within an hour                 t
# 26160       Arben            Unknown     within an hour                 t
# 26161     Giorgos   Rethimno, Greece     within an hour                 t
# 26162       Notos             Greece     within an hour                 f
# 26163    Καλλιόπη            Unknown     within an hour                 f
#
#       host_has_profile_pic  ... review_scores_cleanliness  \
# 0                        t  ...                      4.91
# 1                        t  ...                      4.49
# 2                        t  ...                      4.67
# 3                        t  ...                      5.00
# 4                        t  ...                      4.80
# ...                    ...  ...                       ...
# 26159                    t  ...                      5.00
# 26160                    t  ...                      5.00
# 26161                    t  ...                      5.00
# 26162                    t  ...                      5.00
# 26163                    f  ...                      5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.96                         4.99
# 1                       4.33                         4.43
# 2                       4.87                         4.84
# 3                       5.00                         4.50
# 4                       4.92                         4.94
# ...                      ...                          ...
# 26159                   5.00                         5.00
# 26160                   5.00                         5.00
# 26161                   5.00                         5.00
# 26162                   5.00                         5.00
# 26163                   5.00                         5.00
#
#        review_scores_location  review_scores_value  reviews_per_month  \
# 0                        4.64                 4.92               0.82
# 1                        4.50                 4.18               0.26
# 2                        4.94                 4.66               0.40
# 3                        4.00                 4.50               0.01
# 4                        4.68                 4.88               0.98
# ...                       ...                  ...                ...
# 26159                    4.80                 4.90               0.30
# 26160                    4.80                 4.90               0.30
# 26161                    4.80                 4.90               0.30
# 26162                    4.80                 4.90               0.30
# 26163                    4.80                 4.90               0.30
#
#        estimated_occupancy_l365d  estimated_revenue_l365d   latitude  \
# 0                           48.0                   2352.0  35.330120
# 1                            6.0                    432.0  34.995330
# 2                          168.0                      0.0  35.514390
# 3                            0.0                      0.0  35.496480
# 4                          100.0                   7000.0  35.396160
# ...                          ...                      ...        ...
# 26159                        0.0                      0.0  35.512959
# 26160                        0.0                      0.0  35.512959
# 26161                        0.0                      0.0  35.343478
# 26162                        0.0                      0.0  35.200249
# 26163                        0.0                      0.0  35.211579
#
#        longitude
# 0      25.080120
# 1      24.756540
# 2      24.017930
# 3      23.696480
# 4      25.025410
# ...          ...
# 26159  24.015141
# 26160  24.015141
# 26161  24.727593
# 26162  24.417222
# 26163  26.109334
#
# [26164 rows x 43 columns]

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido bedrooms                          6.000000
# beds                              7.000000
# accommodates                     10.500000
# host_listings_count              32.000000
# host_total_listings_count        39.500000
# bathrooms                         3.500000
# minimum_nights                    7.000000
# maximum_nights                 2677.500000
# minimum_minimum_nights            6.000000
# maximum_minimum_nights            9.500000
# minimum_maximum_nights         2265.000000
# maximum_maximum_nights         2265.000000
# availability_30                  65.000000
# availability_60                 110.500000
# availability_90                 157.500000
# availability_365                532.500000
# number_of_reviews                56.000000
# number_of_reviews_ltm            15.000000
# number_of_reviews_l30d            0.000000
# number_of_reviews_ly             15.000000
# review_scores_rating              5.228750
# review_scores_accuracy            5.240000
# review_scores_cleanliness         5.210000
# review_scores_checkin             5.150000
# review_scores_communication       5.105000
# review_scores_location            5.280000
# review_scores_value               5.235000
# reviews_per_month                 1.115000
# estimated_occupancy_l365d       105.000000
# estimated_revenue_l365d        9870.000000
# latitude                         35.824855
# longitude                        26.807962
# dtype: float64
# Limite inferior permitido bedrooms                         -2.000000
# beds                             -1.000000
# accommodates                     -1.500000
# host_listings_count             -16.000000
# host_total_listings_count       -20.500000
# bathrooms                        -0.500000
# minimum_nights                   -1.000000
# maximum_nights                -1462.500000
# minimum_minimum_nights           -2.000000
# maximum_minimum_nights           -2.500000
# minimum_maximum_nights         -775.000000
# maximum_maximum_nights         -775.000000
# availability_30                 -39.000000
# availability_60                 -45.500000
# availability_90                 -54.500000
# availability_365               -127.500000
# number_of_reviews               -32.000000
# number_of_reviews_ltm            -9.000000
# number_of_reviews_l30d            0.000000
# number_of_reviews_ly             -9.000000
# review_scores_rating              4.618750
# review_scores_accuracy            4.600000
# review_scores_cleanliness         4.650000
# review_scores_checkin             4.750000
# review_scores_communication       4.825000
# review_scores_location            4.400000
# review_scores_value               4.475000
# reviews_per_month                -0.365000
# estimated_occupancy_l365d       -63.000000
# estimated_revenue_l365d       -5922.000000
# latitude                         34.956635
# longitude                        22.348519
# dtype: float64

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        bedrooms  beds  accommodates  host_listings_count  \
# 0           1.0   1.0           3.0                  3.0
# 1           1.0   2.0           4.0                  4.0
# 2           1.0   2.0           2.0                  4.0
# 3           1.0   2.0           6.0                  1.0
# 4           1.0   1.0           2.0                 15.0
# ...         ...   ...           ...                  ...
# 26159       1.0   1.0           2.0                 10.0
# 26160       1.0   1.0           2.0                 10.0
# 26161       4.0   6.0          10.0                  NaN
# 26162       3.0   4.0           6.0                 13.0
# 26163       1.0   2.0           4.0                  4.0
#
#        host_total_listings_count  bathrooms  minimum_nights  maximum_nights  \
# 0                            3.0        1.5             3.0              15
# 1                            4.0        1.0             1.0            1125
# 2                            4.0        1.7             4.0              30
# 3                            1.0        1.0             3.0             730
# 4                           15.0        1.0             5.0              28
# ...                          ...        ...             ...             ...
# 26159                       10.0        1.0             3.0             365
# 26160                       10.0        1.0             3.0             365
# 26161                        NaN        NaN             1.0            1125
# 26162                       25.0        2.0             6.0              45
# 26163                        4.0        1.0             1.0             365
#
#        minimum_minimum_nights  maximum_minimum_nights  ...  \
# 0                         3.0                     3.0  ...
# 1                         1.0                     1.0  ...
# 2                         4.0                     4.0  ...
# 3                         3.0                     3.0  ...
# 4                         5.0                     7.0  ...
# ...                       ...                     ...  ...
# 26159                     3.0                     3.0  ...
# 26160                     3.0                     3.0  ...
# 26161                     1.0                     7.0  ...
# 26162                     5.0                     7.0  ...
# 26163                     1.0                     1.0  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.91                   4.96
# 1                            NaN                    NaN
# 2                           4.67                   4.87
# 3                           5.00                   5.00
# 4                           4.80                   4.92
# ...                          ...                    ...
# 26159                       5.00                   5.00
# 26160                       5.00                   5.00
# 26161                       5.00                   5.00
# 26162                       5.00                   5.00
# 26163                       5.00                   5.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.99                    4.64
# 1                              NaN                    4.50
# 2                             4.84                    4.94
# 3                              NaN                     NaN
# 4                             4.94                    4.68
# ...                            ...                     ...
# 26159                         5.00                    4.80
# 26160                         5.00                    4.80
# 26161                         5.00                    4.80
# 26162                         5.00                    4.80
# 26163                         5.00                    4.80
#
#        review_scores_value  reviews_per_month  estimated_occupancy_l365d  \
# 0                     4.92               0.82                       48.0
# 1                      NaN               0.26                        6.0
# 2                     4.66                NaN                        NaN
# 3                     4.50               0.01                        0.0
# 4                     4.88               0.98                      100.0
# ...                    ...                ...                        ...
# 26159                 4.90               0.30                        0.0
# 26160                 4.90               0.30                        0.0
# 26161                 4.90               0.30                        0.0
# 26162                 4.90               0.30                        0.0
# 26163                 4.90               0.30                        0.0
#
#        estimated_revenue_l365d   latitude  longitude
# 0                       2352.0  35.330120  25.080120
# 1                        432.0  34.995330  24.756540
# 2                          0.0  35.514390  24.017930
# 3                          0.0  35.496480  23.696480
# 4                       7000.0  35.396160  25.025410
# ...                        ...        ...        ...
# 26159                      0.0  35.512959  24.015141
# 26160                      0.0  35.512959  24.015141
# 26161                      0.0  35.343478  24.727593
# 26162                      0.0  35.200249  24.417222
# 26163                      0.0  35.211579  26.109334
#
# [26164 rows x 32 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# bedrooms                        336
# beds                           1044
# accommodates                   1116
# host_listings_count            5299
# host_total_listings_count      5342
# bathrooms                      1647
# minimum_nights                  304
# maximum_nights                    0
# minimum_minimum_nights          866
# maximum_minimum_nights          563
# minimum_maximum_nights            0
# maximum_maximum_nights            0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews              2399
# number_of_reviews_ltm          1753
# number_of_reviews_l30d          886
# number_of_reviews_ly           1763
# review_scores_rating           2509
# review_scores_accuracy         2296
# review_scores_cleanliness      2598
# review_scores_checkin          3081
# review_scores_communication    3546
# review_scores_location         1680
# review_scores_value            1876
# reviews_per_month              2306
# estimated_occupancy_l365d      1996
# estimated_revenue_l365d        2588
# latitude                        206
# longitude                         0
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#        bedrooms  beds  accommodates  host_listings_count  \
# 0           1.0   1.0           3.0                  3.0
# 1           1.0   2.0           4.0                  4.0
# 2           1.0   2.0           2.0                  4.0
# 3           1.0   2.0           6.0                  1.0
# 4           1.0   1.0           2.0                 15.0
# ...         ...   ...           ...                  ...
# 26159       1.0   1.0           2.0                 10.0
# 26160       1.0   1.0           2.0                 10.0
# 26161       4.0   6.0          10.0                  4.5
# 26162       3.0   4.0           6.0                 13.0
# 26163       1.0   2.0           4.0                  4.0
#
#        host_total_listings_count  bathrooms  minimum_nights  maximum_nights  \
# 0                            3.0        1.5             3.0              15
# 1                            4.0        1.0             1.0            1125
# 2                            4.0        1.7             4.0              30
# 3                            1.0        1.0             3.0             730
# 4                           15.0        1.0             5.0              28
# ...                          ...        ...             ...             ...
# 26159                       10.0        1.0             3.0             365
# 26160                       10.0        1.0             3.0             365
# 26161                        5.2        1.5             1.0            1125
# 26162                       25.0        2.0             6.0              45
# 26163                        4.0        1.0             1.0             365
#
#        minimum_minimum_nights  maximum_minimum_nights  ...  \
# 0                         3.0                     3.0  ...
# 1                         1.0                     1.0  ...
# 2                         4.0                     4.0  ...
# 3                         3.0                     3.0  ...
# 4                         5.0                     7.0  ...
# ...                       ...                     ...  ...
# 26159                     3.0                     3.0  ...
# 26160                     3.0                     3.0  ...
# 26161                     1.0                     7.0  ...
# 26162                     5.0                     7.0  ...
# 26163                     1.0                     1.0  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.91                   4.96
# 1                           4.90                   5.00
# 2                           4.67                   4.87
# 3                           5.00                   5.00
# 4                           4.80                   4.92
# ...                          ...                    ...
# 26159                       5.00                   5.00
# 26160                       5.00                   5.00
# 26161                       5.00                   5.00
# 26162                       5.00                   5.00
# 26163                       5.00                   5.00
#
#        review_scores_communication  review_scores_location  \
# 0                             4.99                    4.64
# 1                             5.00                    4.50
# 2                             4.84                    4.94
# 3                             5.00                    4.80
# 4                             4.94                    4.68
# ...                            ...                     ...
# 26159                         5.00                    4.80
# 26160                         5.00                    4.80
# 26161                         5.00                    4.80
# 26162                         5.00                    4.80
# 26163                         5.00                    4.80
#
#        review_scores_value  reviews_per_month  estimated_occupancy_l365d  \
# 0                     4.92               0.82                       48.0
# 1                     4.90               0.26                        6.0
# 2                     4.66               0.30                       20.5
# 3                     4.50               0.01                        0.0
# 4                     4.88               0.98                      100.0
# ...                    ...                ...                        ...
# 26159                 4.90               0.30                        0.0
# 26160                 4.90               0.30                        0.0
# 26161                 4.90               0.30                        0.0
# 26162                 4.90               0.30                        0.0
# 26163                 4.90               0.30                        0.0
#
#        estimated_revenue_l365d   latitude  longitude
# 0                       2352.0  35.330120  25.080120
# 1                        432.0  34.995330  24.756540
# 2                          0.0  35.514390  24.017930
# 3                          0.0  35.496480  23.696480
# 4                       7000.0  35.396160  25.025410
# ...                        ...        ...        ...
# 26159                      0.0  35.512959  24.015141
# 26160                      0.0  35.512959  24.015141
# 26161                      0.0  35.343478  24.727593
# 26162                      0.0  35.200249  24.417222
# 26163                      0.0  35.211579  26.109334
#
# [26164 rows x 32 columns]

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "median"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.median(),1))
data4_iqr

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#       instant_bookable                      property_type        room_type  \
# 0                    t                 Entire rental unit  Entire home/apt
# 1                    t  Private room in bed and breakfast     Private room
# 2                    f                 Entire rental unit  Entire home/apt
# 3                    f                 Entire rental unit  Entire home/apt
# 4                    t                 Entire rental unit  Entire home/apt
# ...                ...                                ...              ...
# 26159                t                       Entire condo  Entire home/apt
# 26160                t                       Entire condo  Entire home/apt
# 26161                t                       Entire villa  Entire home/apt
# 26162                t                       Entire villa  Entire home/apt
# 26163                f                 Entire rental unit  Entire home/apt
#
#                                                amenities  bathrooms_text  \
# 0      ["Hot water", "Bed linens", "Dining table", "W...       1.5 baths
# 1      ["Hot water", "Shampoo", "TV", "Crib", "Exteri...  1 private bath
# 2      ["Hot water", "Exterior security cameras on pr...          1 bath
# 3      ["Kitchen", "Hot tub", "Free parking on premis...          1 bath
# 4      ["Clothing storage: wardrobe", "Garden view", ...          1 bath
# ...                                                  ...             ...
# 26159  ["Hot water", "Cleaning available during stay"...          1 bath
# 26160  ["Hot water", "Cleaning available during stay"...          1 bath
# 26161  ["Hot water", "Crib", "High chair", "Bed linen...         4 baths
# 26162  ["Hot water", "Mosquito net", "Bed linens", "D...         2 baths
# 26163      ["Wifi", "Air conditioning", "Kitchen", "TV"]          1 bath
#
#         host_name      host_location host_response_time host_is_superhost  \
# 0       Emmanouil  Heraklion, Greece     within an hour                 t
# 1        Dimitris     Matala, Greece     within an hour                 f
# 2      Chryssoula     Chania, Greece     within an hour                 f
# 3        Georgios             Greece     within an hour                 f
# 4          George   Iraklion, Greece     within an hour                 t
# ...           ...                ...                ...               ...
# 26159       Arben            Unknown     within an hour                 t
# 26160       Arben            Unknown     within an hour                 t
# 26161     Giorgos   Rethimno, Greece     within an hour                 t
# 26162       Notos             Greece     within an hour                 f
# 26163    Καλλιόπη            Unknown     within an hour                 f
#
#       host_has_profile_pic  ... review_scores_cleanliness  \
# 0                        t  ...                      4.91
# 1                        t  ...                      4.90
# 2                        t  ...                      4.67
# 3                        t  ...                      5.00
# 4                        t  ...                      4.80
# ...                    ...  ...                       ...
# 26159                    t  ...                      5.00
# 26160                    t  ...                      5.00
# 26161                    t  ...                      5.00
# 26162                    t  ...                      5.00
# 26163                    f  ...                      5.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.96                         4.99
# 1                       5.00                         5.00
# 2                       4.87                         4.84
# 3                       5.00                         5.00
# 4                       4.92                         4.94
# ...                      ...                          ...
# 26159                   5.00                         5.00
# 26160                   5.00                         5.00
# 26161                   5.00                         5.00
# 26162                   5.00                         5.00
# 26163                   5.00                         5.00
#
#        review_scores_location  review_scores_value  reviews_per_month  \
# 0                        4.64                 4.92               0.82
# 1                        4.50                 4.90               0.26
# 2                        4.94                 4.66               0.30
# 3                        4.80                 4.50               0.01
# 4                        4.68                 4.88               0.98
# ...                       ...                  ...                ...
# 26159                    4.80                 4.90               0.30
# 26160                    4.80                 4.90               0.30
# 26161                    4.80                 4.90               0.30
# 26162                    4.80                 4.90               0.30
# 26163                    4.80                 4.90               0.30
#
#        estimated_occupancy_l365d  estimated_revenue_l365d   latitude  \
# 0                           48.0                   2352.0  35.330120
# 1                            6.0                    432.0  34.995330
# 2                           20.5                      0.0  35.514390
# 3                            0.0                      0.0  35.496480
# 4                          100.0                   7000.0  35.396160
# ...                          ...                      ...        ...
# 26159                        0.0                      0.0  35.512959
# 26160                        0.0                      0.0  35.512959
# 26161                        0.0                      0.0  35.343478
# 26162                        0.0                      0.0  35.200249
# 26163                        0.0                      0.0  35.211579
#
#        longitude
# 0      25.080120
# 1      24.756540
# 2      24.017930
# 3      23.696480
# 4      25.025410
# ...          ...
# 26159  24.015141
# 26160  24.015141
# 26161  24.727593
# 26162  24.417222
# 26163  26.109334
#
# [26164 rows x 43 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# instant_bookable               0
# property_type                  0
# room_type                      0
# amenities                      0
# bathrooms_text                 0
# host_name                      0
# host_location                  0
# host_response_time             0
# host_is_superhost              0
# host_has_profile_pic           0
# host_identity_verified         0
# bedrooms                       0
# beds                           0
# accommodates                   0
# host_listings_count            0
# host_total_listings_count      0
# bathrooms                      0
# minimum_nights                 0
# maximum_nights                 0
# minimum_minimum_nights         0
# maximum_minimum_nights         0
# minimum_maximum_nights         0
# maximum_maximum_nights         0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# number_of_reviews_ly           0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# estimated_occupancy_l365d      0
# estimated_revenue_l365d        0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("pais_limpios.csv")

# %%
#Cuartiles detecta más outliers que desviación estándar
