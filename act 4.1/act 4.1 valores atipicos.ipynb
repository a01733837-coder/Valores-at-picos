# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI3002C/blob/main/4_Valores_at%C3%ADpicos_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('ventas_totales_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           39 non-null     int64
#  1   indice_tiempo                        39 non-null     object
#  2   ventas_precios_corrientes            39 non-null     float64
#  3   ventas_precios_constantes            39 non-null     float64
#  4   ventas_totales_canal_venta           39 non-null     float64
#  5   salon_ventas                         39 non-null     float64
#  6   canales_on_line                      39 non-null     float64
#  7   ventas_totales_medio_pago            39 non-null     float64
#  8   efectivo                             39 non-null     float64
#  9   tarjetas_debito                      39 non-null     float64
#  10  tarjetas_credito                     39 non-null     float64
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_30260\419970050.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 =data.fillna(method="bfill")
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# 5            5    01/06/2017                    29132.7
# 6            6    01/07/2017                    31182.3
# 7           10    01/11/2017                    33629.0
# 8           11    01/12/2017                    40766.3
# 9           12    01/01/2018                    32479.2
# 10          26    01/03/2019                    51065.7
# 11          27    01/04/2019                    49621.4
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#Creo 2 dataframe para poder procesar los outliers
cuantitativas= data1.iloc[ : , 1:23 ]
cualitativas= data1.iloc[ : , [0] ]

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
data1["indice_tiempo"] = pd.to_datetime(data1.get("indice_tiempo"), format="%d/%m/%Y", errors="ignore")
# Out:
# C:\Users\sammm\AppData\Local\Temp\ipykernel_30260\946277982.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data1["indice_tiempo"] = pd.to_datetime(data1.get("indice_tiempo"), format="%d/%m/%Y", errors="ignore")

# %%
cuantitativas = data1.select_dtypes(include=[np.number])     # <- DataFrame numérico
y = cuantitativas.copy()

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Unnamed: 0                             9.069159e+01
# ventas_precios_corrientes              2.251921e+05
# ventas_precios_constantes              4.381962e+04
# ventas_totales_canal_venta             2.094359e+08
# salon_ventas                           1.995289e+08
# canales_on_line                        7.957221e+06
# ventas_totales_medio_pago              2.067341e+08
# efectivo                               6.213790e+07
# tarjetas_debito                        5.949420e+07
# tarjetas_credito                       7.486880e+07
# otros_medios                           1.094475e+07
# ventas_totales_grupo_articulos         2.067341e+08
# subtotal_ventas_alimentos_bebidas      1.438848e+08
# bebidas                                2.789106e+07
# almacen                                5.495765e+07
# panaderia                              6.911236e+06
# lacteos                                2.212274e+07
# carnes                                 2.486224e+07
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#     Unnamed: 0  ventas_precios_corrientes  ventas_precios_constantes  \
# 0            0                    27858.9                    27477.3
# 1            1                    25994.2                    25223.4
# 2            2                    27780.0                    26334.3
# 3            3                    29134.3                    27045.9
# 4            4                    27969.0                    25631.9
# 5            5                    29132.7                    26365.4
# 6            6                    31182.3                    27819.4
# 7           10                    33629.0                    28425.3
# 8           11                    40766.3                    34084.5
# 9           12                    32479.2                    26736.7
# 10          26                    51065.7                    24647.7
# 11          27                    49621.4                    23073.8
# 12          28                    50778.3                    22852.1
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# ventas_precios_corrientes              0
# ventas_precios_constantes              2
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe, descargar 
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#     Unnamed: 0  ventas_precios_corrientes  ventas_precios_constantes  \
# 0            0                    27858.9                    27477.3
# 1            1                    25994.2                    25223.4
# 2            2                    27780.0                    26334.3
# 3            3                    29134.3                    27045.9
# 4            4                    27969.0                    25631.9
# 5            5                    29132.7                    26365.4
# 6            6                    31182.3                    27819.4
# 7           10                    33629.0                    28425.3
# 8           11                    40766.3                    34084.5
# 9           12                    32479.2                    26736.7
# 10          26                    51065.7                    24647.7
# 11          27                    49621.4                    23073.8
# 12          28                    50778.3                    22852.1
# ...

# %%
#Convertir DataFrame a CSV
data_clean.to_csv("data_clean_desviación.csv")

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios_desviación = pd.concat([cualitativas, data_clean], axis=1)
Datos_limpios_desviación
# Out:
#     Unnamed: 0  Unnamed: 0  ventas_precios_corrientes  \
# 0            0           0                    27858.9
# 1            1           1                    25994.2
# 2            2           2                    27780.0
# 3            3           3                    29134.3
# 4            4           4                    27969.0
# 5            5           5                    29132.7
# 6            6           6                    31182.3
# 7           10          10                    33629.0
# 8           11          11                    40766.3
# 9           12          12                    32479.2
# 10          26          26                    51065.7
# 11          27          27                    49621.4
# 12          28          28                    50778.3
# 13          29          29                    54413.4
# 14          30          30                    55044.5
# 15          31          31                    59672.1
# ...

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido Unnamed: 0                             9.150000e+01
# ventas_precios_corrientes              2.152227e+05
# ventas_precios_constantes              3.235365e+04
# ventas_totales_canal_venta             1.866579e+08
# salon_ventas                           1.766873e+08
# canales_on_line                        9.429497e+06
# ventas_totales_medio_pago              1.866579e+08
# efectivo                               5.624256e+07
# tarjetas_debito                        5.125509e+07
# tarjetas_credito                       6.932751e+07
# otros_medios                           1.149514e+07
# ventas_totales_grupo_articulos         1.866579e+08
# subtotal_ventas_alimentos_bebidas      1.322696e+08
# bebidas                                2.181924e+07
# almacen                                5.154095e+07
# panaderia                              5.784870e+06
# lacteos                                1.908329e+07
# carnes                                 2.453382e+07
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#     Unnamed: 0  ventas_precios_corrientes  ventas_precios_constantes  \
# 0            0                    27858.9                    27477.3
# 1            1                    25994.2                    25223.4
# 2            2                    27780.0                    26334.3
# 3            3                    29134.3                    27045.9
# 4            4                    27969.0                    25631.9
# 5            5                    29132.7                    26365.4
# 6            6                    31182.3                    27819.4
# 7           10                    33629.0                    28425.3
# 8           11                    40766.3                        NaN
# 9           12                    32479.2                    26736.7
# 10          26                    51065.7                    24647.7
# 11          27                    49621.4                    23073.8
# 12          28                    50778.3                    22852.1
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# ventas_precios_corrientes              0
# ventas_precios_constantes              3
# ventas_totales_canal_venta             0
# salon_ventas                           1
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               1
# tarjetas_debito                        1
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              2
# lacteos                                1
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         2
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    1
# electronicos_articulos_hogar           0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#     Unnamed: 0  ventas_precios_corrientes  ventas_precios_constantes  \
# 0            0                    27858.9                    27477.3
# 1            1                    25994.2                    25223.4
# 2            2                    27780.0                    26334.3
# 3            3                    29134.3                    27045.9
# 4            4                    27969.0                    25631.9
# 5            5                    29132.7                    26365.4
# 6            6                    31182.3                    27819.4
# 7           10                    33629.0                    28425.3
# 8           11                    40766.3                    25062.8
# 9           12                    32479.2                    26736.7
# 10          26                    51065.7                    24647.7
# 11          27                    49621.4                    23073.8
# 12          28                    50778.3                    22852.1
# ...

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#     Unnamed: 0  Unnamed: 0  ventas_precios_corrientes  \
# 0            0           0                    27858.9
# 1            1           1                    25994.2
# 2            2           2                    27780.0
# 3            3           3                    29134.3
# 4            4           4                    27969.0
# 5            5           5                    29132.7
# 6            6           6                    31182.3
# 7           10          10                    33629.0
# 8           11          11                    40766.3
# 9           12          12                    32479.2
# 10          26          26                    51065.7
# 11          27          27                    49621.4
# 12          28          28                    50778.3
# 13          29          29                    54413.4
# 14          30          30                    55044.5
# 15          31          31                    59672.1
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# Unnamed: 0                             0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios.csv")

# %%
# Este es el código para abrir el csv de la tarea

#Carga de un archivo .xlsx desde un libro con varias páginas
df= pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2023')
df
